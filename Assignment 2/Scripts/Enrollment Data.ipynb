# %%
import pandas as pd
import numpy as np

# %%
enroll = pd.read_csv("enrolment-by-institutions.csv", na_values = "-")
enroll = enroll[enroll.year >= 2010]
enroll = enroll[enroll.year <= 2014].set_index(["year", "sex"])
enroll = enroll.fillna(0)

col = enroll.columns

for value in col:
    enroll[value] = enroll[value].astype("int32")
enroll
# Out:
#             nus    ntu   smu   sit  sutd  suss   nie  singapore_polytechnic  \
# year sex
# 2010 MF   25189  22862  6721   523     0     0  2816                  15928
#      F    13067  11389  3525   275     0     0  1886                   6453
# 2011 MF   25513  23040  6853  1416     0     0  2579                  15949
#      F    13066  11354  3523   732     0     0  1759                   6432
# 2012 MF   25979  22862  7108  2587   327     0  2445                  15972
#      F    13295  11386  3684  1246   149     0  1624                   6327
# 2013 MF   26156  22777  7297  3051   583     0  1838                  15878
#      F    13532  11517  3789  1317   249     0  1216                   6167
# 2014 MF   26797  23021  7515  3557   886   217  1913                  15905
#      F    14042  11623  3883  1482   363   145  1313                   6175
#
#           ngee_ann_polytechnic  temasek_polytechnic  nanyang_polytechnic  \
# year sex
# 2010 MF                  15942                15933                16183
#      F                    7655                 7804                 8387
# 2011 MF                  16139                16020                16408
#      F                    7703                 7894                 8440
# 2012 MF                  16430                16005                16076
#      F                    7788                 7855                 8197
# 2013 MF                  16581                16250                16266
#      F                    7866                 7934                 8242
# 2014 MF                  16227                16138                16092
#      F                    7758                 7900                 8189
#
#           republic_polytechnic  lasalle_diploma  lasalle_degree  nafa_diploma  \
# year sex
# 2010 MF                  13003             1754               0          2269
#      F                    6729             1137               0          1532
# 2011 MF                  13927             1623               0          2217
#      F                    7209             1011               0          1510
# 2012 MF                  14520             1353            1081          2225
#      F                    7583              854             771          1531
# 2013 MF                  14995             1253            1290          2037
#      F                    7910              769             956          1419
# 2014 MF                  14952             1190            1176          2022
#      F                    7914              773             846          1440
#
#           nafa_degree    ite
# year sex
# 2010 MF             0  24789
#      F              0   8856
# 2011 MF            20  25279
#      F              9   9158
# 2012 MF            43  25370
#      F             22   9085
# 2013 MF            51  26288
#      F             25   9428
# 2014 MF            53  28036
#      F             31  10249

# %%
male = []
for i in range(len(enroll)-1):
    if enroll.index[i][0] == enroll.index[i+1][0]:
        male.append((enroll.iloc[i] - enroll.iloc[i + 1]))

# %%
male_data = pd.DataFrame(columns = ["year",
                               "sex",
                               "nus", 
                               "ntu",
                               "smu", 
                               "sit", 
                               "sutd",
                               "suss", 
                               "nie", 
                               "singapore_polytechnic",
                               "ngee_ann_polytechnic", 
                               "temasek_polytechnic",
                               "nanyang_polytechnic", 
                               "republic_polytechnic", 
                               "lasalle_diploma",
                               "lasalle_degree", 
                               "nafa_diploma", 
                               "nafa_degree", 
                               "ite"])

for i in range(len(male)):
    male_data = male_data.append({"year" : enroll.index[i*2][0],
                "sex" : "M",
                "nus" : int(male[i][0]),
                "ntu" : int(male[i][1]),
                "smu" : int(male[i][2]),
                "sit" : int(male[i][3]),
                "sutd": int(male[i][4]),
                "suss" : int(male[i][5]),
                "nie" : int(male[i][6]),
                "singapore_polytechnic" : int(male[i][7]),
                "ngee_ann_polytechnic" : int(male[i][8]),
                "temasek_polytechnic" : int(male[i][9]),
                "nanyang_polytechnic" : int(male[i][10]),
                "republic_polytechnic" : int(male[i][11]),
                "lasalle_diploma" : int(male[i][12]),
                "lasalle_degree" : int(male[i][13]),
                "nafa_diploma" : int(male[i][14]),
                "nafa_degree" : int(male[i][15]),
                "ite" :  int(male[i][16])}, ignore_index=True)

# %%
male_data = male_data.set_index(["year", "sex"])
male_data
# Out:
#             nus    ntu   smu   sit sutd suss  nie singapore_polytechnic  \
# year sex
# 2010 M    12122  11473  3196   248    0    0  930                  9475
# 2011 M    12447  11686  3330   684    0    0  820                  9517
# 2012 M    12684  11476  3424  1341  178    0  821                  9645
# 2013 M    12624  11260  3508  1734  334    0  622                  9711
# 2014 M    12755  11398  3632  2075  523   72  600                  9730
#
#          ngee_ann_polytechnic temasek_polytechnic nanyang_polytechnic  \
# year sex
# 2010 M                   8287                8129                7796
# 2011 M                   8436                8126                7968
# 2012 M                   8642                8150                7879
# 2013 M                   8715                8316                8024
# 2014 M                   8469                8238                7903
#
#          republic_polytechnic lasalle_diploma lasalle_degree nafa_diploma  \
# year sex
# 2010 M                   6274             617              0          737
# 2011 M                   6718             612              0          707
# 2012 M                   6937             499            310          694
# 2013 M                   7085             484            334          618
# 2014 M                   7038             417            330          582
#
#          nafa_degree    ite
# year sex
# 2010 M             0  15933
# 2011 M            11  16121
# 2012 M            21  16285
# 2013 M            26  16860
# 2014 M            22  17787

# %%
enroll = pd.concat([male_data, enroll], sort = True).sort_index()
enroll
# Out:
#             ite lasalle_degree lasalle_diploma nafa_degree nafa_diploma  \
# year sex
# 2010 F     8856              0            1137           0         1532
#      M    15933              0             617           0          737
#      MF   24789              0            1754           0         2269
# 2011 F     9158              0            1011           9         1510
#      M    16121              0             612          11          707
#      MF   25279              0            1623          20         2217
# 2012 F     9085            771             854          22         1531
#      M    16285            310             499          21          694
#      MF   25370           1081            1353          43         2225
# 2013 F     9428            956             769          25         1419
#      M    16860            334             484          26          618
#      MF   26288           1290            1253          51         2037
# 2014 F    10249            846             773          31         1440
#      M    17787            330             417          22          582
#      MF   28036           1176            1190          53         2022
#
#          nanyang_polytechnic ngee_ann_polytechnic   nie    ntu    nus  \
# year sex
# 2010 F                  8387                 7655  1886  11389  13067
#      M                  7796                 8287   930  11473  12122
#      MF                16183                15942  2816  22862  25189
# 2011 F                  8440                 7703  1759  11354  13066
#      M                  7968                 8436   820  11686  12447
#      MF                16408                16139  2579  23040  25513
# 2012 F                  8197                 7788  1624  11386  13295
#      M                  7879                 8642   821  11476  12684
#      MF                16076                16430  2445  22862  25979
# 2013 F                  8242                 7866  1216  11517  13532
#      M                  8024                 8715   622  11260  12624
#      MF                16266                16581  1838  22777  26156
# 2014 F                  8189                 7758  1313  11623  14042
#      M                  7903                 8469   600  11398  12755
#      MF                16092                16227  1913  23021  26797
#
#          republic_polytechnic singapore_polytechnic   sit   smu suss sutd  \
# year sex
# 2010 F                   6729                  6453   275  3525    0    0
#      M                   6274                  9475   248  3196    0    0
#      MF                 13003                 15928   523  6721    0    0
# 2011 F                   7209                  6432   732  3523    0    0
#      M                   6718                  9517   684  3330    0    0
#      MF                 13927                 15949  1416  6853    0    0
# 2012 F                   7583                  6327  1246  3684    0  149
#      M                   6937                  9645  1341  3424    0  178
#      MF                 14520                 15972  2587  7108    0  327
# 2013 F                   7910                  6167  1317  3789    0  249
#      M                   7085                  9711  1734  3508    0  334
#      MF                 14995                 15878  3051  7297    0  583
# 2014 F                   7914                  6175  1482  3883  145  363
#      M                   7038                  9730  2075  3632   72  523
#      MF                 14952                 15905  3557  7515  217  886
#
#          temasek_polytechnic
# year sex
# 2010 F                  7804
#      M                  8129
#      MF                15933
# 2011 F                  7894
#      M                  8126
#      MF                16020
# 2012 F                  7855
#      M                  8150
#      MF                16005
# 2013 F                  7934
#      M                  8316
#      MF                16250
# 2014 F                  7900
#      M                  8238
#      MF                16138

# %%
enroll.to_csv("enroll_data.csv")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

merged = pd.read_csv(r"C:\Users\Jurgen\Desktop\PDS-Assignment-1\Assignment 2\After Cleansing\Merged.csv")
merged = merged[merged.year >= 2000]
merged
# Out:
#      year sex  lasalle_degree  nafa_degree   nie    ntu    nus   sit   smu  \
# 54   2000   F               0            0  2247   6223  11341     0   212
# 55   2000  MF               0            0  3072  14583  21233     0   305
# 56   2000   M               0            0   825   8360   9892     0    93
# 57   2001   F               0            0  2292   6504  11781     0   579
# 58   2001  MF               0            0  3095  15008  22172     0   803
# ..    ...  ..             ...          ...   ...    ...    ...   ...   ...
# 292  2013   F             318           22   899   3266   3350   695   920
# 293  2013  MF             466           34  1292   6174   6446  1494  1779
# 294  2014   M             110            5   310   3037   3094   995   984
# 295  2014  MF             429           15  1153   5990   6700  1744  1887
# 296  2014   F             319           10   843   2953   3606   749   903
#
#      suss  sutd  total      type
# 54      0     0  20023    enroll
# 55      0     0  39193    enroll
# 56      0     0  19170    enroll
# 57      0     0  21156    enroll
# 58      0     0  41078    enroll
# ..    ...   ...    ...       ...
# 292     0   107   9577  graduate
# 293     0   267  17952  graduate
# 294    56   182   8773  graduate
# 295   168   334  18420  graduate
# 296   112   152   9647  graduate
#
# [135 rows x 13 columns]

# %%
NUS = merged[["year", "sex","nus", "total", "type"]]
NUS
# Out:
#      year sex    nus  total      type
# 54   2000   F  11341  20023    enroll
# 55   2000  MF  21233  39193    enroll
# 56   2000   M   9892  19170    enroll
# 57   2001   F  11781  21156    enroll
# 58   2001  MF  22172  41078    enroll
# ..    ...  ..    ...    ...       ...
# 292  2013   F   3350   9577  graduate
# 293  2013  MF   6446  17952  graduate
# 294  2014   M   3094   8773  graduate
# 295  2014  MF   6700  18420  graduate
# 296  2014   F   3606   9647  graduate
#
# [135 rows x 5 columns]

# %%
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(15.7,8.27)})
ax = sns.barplot(x="year", y="nus", hue= "type", data=NUS, palette="GnBu_d")

ax.set(xlabel='Year', ylabel='Total Number Of Students In NUS')
plt.title("Colors vs Values")


plt.show(ax)

# %%
intake_grad = NUS[NUS.type !="enroll"]
intake_grad = intake_grad[intake_grad.sex != "MF"].reset_index(drop = True)
intake_grad
# Out:
#     year sex   nus  total      type
# 0   2000   F  3437   7326    intake
# 1   2000   M  2984   6092    intake
